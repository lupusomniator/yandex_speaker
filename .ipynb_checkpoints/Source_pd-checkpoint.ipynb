# %% [markdown]
# # YANDEX ML

# %%
import pandas as pd
import pymorphy2
from  TextPreprocessing import TextPreprocessing
import pickle
from  profiler import Profiler
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Степан\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv('train.tsv',
                         names=['context_id', 'context_2', 'context_1', 'context_0', 'reply_id', 'reply',
                                'label', 'confidence'],
                        header=None, sep='\t')

# %%
df.head()
# Out:
#     context_id                                          context_2  \
# 0  22579918886  кликни на меня а потом на надпись " видео - зв...
# 1  22579918886  кликни на меня а потом на надпись " видео - зв...
# 2  22579918886  кликни на меня а потом на надпись " видео - зв...
# 3  22579918886  кликни на меня а потом на надпись " видео - зв...
# 4  22579918886  кликни на меня а потом на надпись " видео - зв...
#
#            context_1                context_0 reply_id  \
# 0  о , я тебя вижу .  ладно , повесь трубку .        0
# 1  о , я тебя вижу .  ладно , повесь трубку .        1
# 2  о , я тебя вижу .  ладно , повесь трубку .        2
# 3  о , я тебя вижу .  ладно , повесь трубку .        3
# 4  о , я тебя вижу .  ладно , повесь трубку .        4
#
#                       reply    label    confidence
# 0                 не могу .     good  0.8753516175
# 1    нет , звонить буду я .  neutral  0.9009682113
# 2  слушай , я не мог уйти .      bad  0.8843202145
# 3   я не прекращу звонить .     good  0.9825304673
# 4              я звоню им .     good  0.8380535096

# %%
df_sparce = []
col_name = ['context_0','context_1','context_2']
# Один контекст
df_sparce.append(df[pd.isnull(df['context_2']) & pd.isnull(df['context_1'])])

# Два контекста
df_sparce.append(df[pd.isnull(df['context_2']) & pd.notnull(df['context_1'])])

# Три контекста
df_sparce.append(df[pd.notnull(df['context_2']) & pd.notnull(df['context_1'])])

# %%
tp = TextPreprocessing()
col_amount = 1
df_canon = []
with Profiler():
    for df_part in df_sparce:
        df_canon.append([])
        for i in range(col_amount):
            df_canon[col_amount-1].append((df_part[col_name[i]].map(tp.preprocess_sentence)).map(tp.list_to_text))
        col_amount+=1

# %%
with Profiler():
    with open("canonized",'wb') as file:
        pickle.dump(df_canon, file)
# Out:
# [[49               имя_NOUN дать_VERB родитель_NOUN
#   50               имя_NOUN дать_VERB родитель_NOUN
#   51               имя_NOUN дать_VERB родитель_NOUN
#   52               имя_NOUN дать_VERB родитель_NOUN
#   53               имя_NOUN дать_VERB родитель_NOUN
#   54               имя_NOUN дать_VERB родитель_NOUN
#   67                     почему_ADV развестись_VERB
#   68                     почему_ADV развестись_VERB
#   69                     почему_ADV развестись_VERB
#   70                     почему_ADV развестись_VERB
#   71                     почему_ADV развестись_VERB
#   72                     почему_ADV развестись_VERB
#   91                        дот_NOUN позвонить_VERB
#   92                        дот_NOUN позвонить_VERB
#   93                        дот_NOUN позвонить_VERB
#   94                        дот_NOUN позвонить_VERB
#   95                        дот_NOUN позвонить_VERB
#   96                        дот_NOUN позвонить_VERB
#   150                                   дэйвис_NOUN
#   151                                   дэйвис_NOUN
#   152                                   дэйвис_NOUN
#   153                                   дэйвис_NOUN
#   154                                   дэйвис_NOUN
#   155                                   дэйвис_NOUN
#   174                                  сказать_VERB
#   175                                  сказать_VERB
#   176                                  сказать_VERB
#   177                                  сказать_VERB
#   178                                  сказать_VERB
#   179                                  сказать_VERB
#                              ...
#   93241                       любить_VERB суши_NOUN
#   93242                       любить_VERB суши_NOUN
#   93243                       любить_VERB суши_NOUN
#   93244                       любить_VERB суши_NOUN
#   93245                       любить_VERB суши_NOUN
#   93246                       любить_VERB суши_NOUN
#   93253                      это_PART гипотеза_NOUN
#   93254                      это_PART гипотеза_NOUN
#   93255                      это_PART гипотеза_NOUN
#   93256                      это_PART гипотеза_NOUN
#   93257                      это_PART гипотеза_NOUN
#   93258                      это_PART гипотеза_NOUN
#   93283                вернуться_VERB говорить_VERB
#   93284                вернуться_VERB говорить_VERB
#   93285                вернуться_VERB говорить_VERB
#   93286                вернуться_VERB говорить_VERB
#   93287                вернуться_VERB говорить_VERB
#   93288                вернуться_VERB говорить_VERB
#   93295    твой_ADJ мама_NOUN дом_NOUN секунда_NOUN
#   93296    твой_ADJ мама_NOUN дом_NOUN секунда_NOUN
#   93297    твой_ADJ мама_NOUN дом_NOUN секунда_NOUN
#   93298    твой_ADJ мама_NOUN дом_NOUN секунда_NOUN
#   93299    твой_ADJ мама_NOUN дом_NOUN секунда_NOUN
#   93300    твой_ADJ мама_NOUN дом_NOUN секунда_NOUN
#   93307                                 давать_VERB
#   93308                                 давать_VERB
#   93309                                 давать_VERB
#   93310                                 давать_VERB
#   93311                                 давать_VERB
#   93312                                 давать_VERB
#   Name: context_0, Length: 23804, dtype: object],
#  [61                                              хотя_CCONJ
#   62                                              хотя_CCONJ
#   63                                              хотя_CCONJ
#   64                                              хотя_CCONJ
#   65                                              хотя_CCONJ
#   66                                              хотя_CCONJ
#   115                                            понятно_ADV
#   116                                            понятно_ADV
#   117                                            понятно_ADV
#   118                                            понятно_ADV
#   119                                            понятно_ADV
#   120                                            понятно_ADV
#   121                     лишь_PART дрянный_ADJ ребенок_NOUN
#   122                     лишь_PART дрянный_ADJ ребенок_NOUN
#   123                     лишь_PART дрянный_ADJ ребенок_NOUN
#   124                     лишь_PART дрянный_ADJ ребенок_NOUN
#   125                     лишь_PART дрянный_ADJ ребенок_NOUN
#   126                     лишь_PART дрянный_ADJ ребенок_NOUN
#   138                                       чувствовать_VERB
#   139                                       чувствовать_VERB
#   140                                       чувствовать_VERB
#   141                                       чувствовать_VERB
#   142                                       чувствовать_VERB
#   143                                       чувствовать_VERB
#   182                                             завтра_ADV
#   183                                             завтра_ADV
#   184                                             завтра_ADV
#   185                                             завтра_ADV
#   186                                             завтра_ADV
#   187                                             завтра_ADV
#                                  ...
#   93229      хороший_ADJ вещий_ADJ жизнь_NOUN бесплатный_ADJ
#   93230      хороший_ADJ вещий_ADJ жизнь_NOUN бесплатный_ADJ
#   93231      хороший_ADJ вещий_ADJ жизнь_NOUN бесплатный_ADJ
#   93232      хороший_ADJ вещий_ADJ жизнь_NOUN бесплатный_ADJ
#   93233      хороший_ADJ вещий_ADJ жизнь_NOUN бесплатный_ADJ
#   93234      хороший_ADJ вещий_ADJ жизнь_NOUN бесплатный_ADJ
#   93271    закончить_VERB получить_VERB неплохой_ADJ куш_...
#   93272    закончить_VERB получить_VERB неплохой_ADJ куш_...
#   93273    закончить_VERB получить_VERB неплохой_ADJ куш_...
#   93274    закончить_VERB получить_VERB неплохой_ADJ куш_...
#   93275    закончить_VERB получить_VERB неплохой_ADJ куш_...
#   93276    закончить_VERB получить_VERB неплохой_ADJ куш_...
#   93277                               спасти_VERB жизнь_NOUN
#   93278                               спасти_VERB жизнь_NOUN
#   93279                               спасти_VERB жизнь_NOUN
#   93280                               спасти_VERB жизнь_NOUN
#   93281                               спасти_VERB жизнь_NOUN
#   93282                               спасти_VERB жизнь_NOUN
#   93301                              удача_NOUN мальчик_NOUN
#   93302                              удача_NOUN мальчик_NOUN
#   93303                              удача_NOUN мальчик_NOUN
#   93304                              удача_NOUN мальчик_NOUN
#   93305                              удача_NOUN мальчик_NOUN
#   93306                              удача_NOUN мальчик_NOUN
#   93313                                         серьезно_ADV
#   93314                                         серьезно_ADV
#   93315                                         серьезно_ADV
#   93316                                         серьезно_ADV
#   93317                                         серьезно_ADV
#   93318                                         серьезно_ADV
#   Name: context_0, Length: 22940, dtype: object,
#   61                                                это_PART
#   62                                                это_PART
#   63                                                это_PART
#   64                                                это_PART
#   65                                                это_PART
#   66                                                это_PART
#   115                                           сказать_VERB
#   116                                           сказать_VERB
#   117                                           сказать_VERB
#   118                                           сказать_VERB
#   119                                           сказать_VERB
#   120                                           сказать_VERB
#   121                                  центр_NOUN город_NOUN
#   122                                  центр_NOUN город_NOUN
#   123                                  центр_NOUN город_NOUN
#   124                                  центр_NOUN город_NOUN
#   125                                  центр_NOUN город_NOUN
#   126                                  центр_NOUN город_NOUN
#   138      чувствовать_VERB необходимость_NOUN носить_VER...
#   139      чувствовать_VERB необходимость_NOUN носить_VER...
#   140      чувствовать_VERB необходимость_NOUN носить_VER...
#   141      чувствовать_VERB необходимость_NOUN носить_VER...
#   142      чувствовать_VERB необходимость_NOUN носить_VER...
#   143      чувствовать_VERB необходимость_NOUN носить_VER...
#   182                                             завтра_ADV
#   183                                             завтра_ADV
#   184                                             завтра_ADV
#   185                                             завтра_ADV
#   186                                             завтра_ADV
#   187                                             завтра_ADV
#                                  ...
#   93229                     любовь_NOUN прийти_VERB весь_ADJ
#   93230                     любовь_NOUN прийти_VERB весь_ADJ
#   93231                     любовь_NOUN прийти_VERB весь_ADJ
#   93232                     любовь_NOUN прийти_VERB весь_ADJ
#   93233                     любовь_NOUN прийти_VERB весь_ADJ
#   93234                     любовь_NOUN прийти_VERB весь_ADJ
#   93271        ладный_ADJ тибер_NOUN любить_VERB деньга_NOUN
#   93272        ладный_ADJ тибер_NOUN любить_VERB деньга_NOUN
#   93273        ладный_ADJ тибер_NOUN любить_VERB деньга_NOUN
#   93274        ладный_ADJ тибер_NOUN любить_VERB деньга_NOUN
#   93275        ладный_ADJ тибер_NOUN любить_VERB деньга_NOUN
#   93276        ладный_ADJ тибер_NOUN любить_VERB деньга_NOUN
#   93277                              следующий_ADJ удар_NOUN
#   93278                              следующий_ADJ удар_NOUN
#   93279                              следующий_ADJ удар_NOUN
#   93280                              следующий_ADJ удар_NOUN
#   93281                              следующий_ADJ удар_NOUN
#   93282                              следующий_ADJ удар_NOUN
#   93301              счастливо_ADV оставаться_VERB папа_NOUN
#   93302              счастливо_ADV оставаться_VERB папа_NOUN
#   93303              счастливо_ADV оставаться_VERB папа_NOUN
#   93304              счастливо_ADV оставаться_VERB папа_NOUN
#   93305              счастливо_ADV оставаться_VERB папа_NOUN
#   93306              счастливо_ADV оставаться_VERB папа_NOUN
#   93313                              неделя_NOUN байрон_NOUN
#   93314                              неделя_NOUN байрон_NOUN
#   93315                              неделя_NOUN байрон_NOUN
#   93316                              неделя_NOUN байрон_NOUN
#   93317                              неделя_NOUN байрон_NOUN
#   93318                              неделя_NOUN байрон_NOUN
#   Name: context_1, Length: 22940, dtype: object],
#  [0                     ладный_ADJ повесить_VERB трубка_NOUN
#   1                     ладный_ADJ повесить_VERB трубка_NOUN
#   2                     ладный_ADJ повесить_VERB трубка_NOUN
#   3                     ладный_ADJ повесить_VERB трубка_NOUN
#   4                     ладный_ADJ повесить_VERB трубка_NOUN
#   5                     ладный_ADJ повесить_VERB трубка_NOUN
#   6        пытаться_VERB добраться_VERB кажется_CCONJ еха...
#   7        пытаться_VERB добраться_VERB кажется_CCONJ еха...
#   8        пытаться_VERB добраться_VERB кажется_CCONJ еха...
#   9        пытаться_VERB добраться_VERB кажется_CCONJ еха...
#   10       пытаться_VERB добраться_VERB кажется_CCONJ еха...
#   11       пытаться_VERB добраться_VERB кажется_CCONJ еха...
#   12                               знать_VERB понаслышке_ADV
#   13                               знать_VERB понаслышке_ADV
#   14                               знать_VERB понаслышке_ADV
#   15                               знать_VERB понаслышке_ADV
#   16                               знать_VERB понаслышке_ADV
#   17                               знать_VERB понаслышке_ADV
#   18                                             хороший_ADJ
#   19                                             хороший_ADJ
#   20                                             хороший_ADJ
#   21                                             хороший_ADJ
#   22                                             хороший_ADJ
#   23                                             хороший_ADJ
#   24                                          нравиться_VERB
#   25                                          нравиться_VERB
#   26                                          нравиться_VERB
#   27                                          нравиться_VERB
#   28                                          нравиться_VERB
#   29                                          нравиться_VERB
#                                  ...
#   93319    недооценивать_VERB сила_NOUN обычный_ADJ челов...
#   93320    недооценивать_VERB сила_NOUN обычный_ADJ челов...
#   93321    недооценивать_VERB сила_NOUN обычный_ADJ челов...
#   93322    недооценивать_VERB сила_NOUN обычный_ADJ челов...
#   93323    недооценивать_VERB сила_NOUN обычный_ADJ челов...
#   93324    недооценивать_VERB сила_NOUN обычный_ADJ челов...
#   93325                                           вкусно_ADV
#   93326                                           вкусно_ADV
#   93327                                           вкусно_ADV
#   93328                                           вкусно_ADV
#   93329                                           вкусно_ADV
#   93330                                           вкусно_ADV
#   93331                                вызвать_VERB сюда_ADV
#   93332                                вызвать_VERB сюда_ADV
#   93333                                вызвать_VERB сюда_ADV
#   93334                                вызвать_VERB сюда_ADV
#   93335                                вызвать_VERB сюда_ADV
#   93336                                вызвать_VERB сюда_ADV
#   93337
#   93338
#   93339
#   93340
#   93341
#   93342
#   93343                           окружный_ADJ прокурор_NOUN
#   93344                           окружный_ADJ прокурор_NOUN
#   93345                           окружный_ADJ прокурор_NOUN
#   93346                           окружный_ADJ прокурор_NOUN
#   93347                           окружный_ADJ прокурор_NOUN
#   93348                           окружный_ADJ прокурор_NOUN
#   Name: context_0, Length: 46605, dtype: object,
#   0                                              видеть_VERB
#   1                                              видеть_VERB
#   2                                              видеть_VERB
#   3                                              видеть_VERB
#   4                                              видеть_VERB
#   5                                              видеть_VERB
#   6                  слушать_VERB жена_NOUN заблудиться_VERB
#   7                  слушать_VERB жена_NOUN заблудиться_VERB
#   8                  слушать_VERB жена_NOUN заблудиться_VERB
#   9                  слушать_VERB жена_NOUN заблудиться_VERB
#   10                 слушать_VERB жена_NOUN заблудиться_VERB
#   11                 слушать_VERB жена_NOUN заблудиться_VERB
#   12                                           кажется_CCONJ
#   13                                           кажется_CCONJ
#   14                                           кажется_CCONJ
#   15                                           кажется_CCONJ
#   16                                           кажется_CCONJ
#   17                                           кажется_CCONJ
#   18                      хороший_ADJ пес_NOUN линдсить_VERB
#   19                      хороший_ADJ пес_NOUN линдсить_VERB
#   20                      хороший_ADJ пес_NOUN линдсить_VERB
#   21                      хороший_ADJ пес_NOUN линдсить_VERB
#   22                      хороший_ADJ пес_NOUN линдсить_VERB
#   23                      хороший_ADJ пес_NOUN линдсить_VERB
#   24       предпочитать_VERB напарник_NOUN использовать_V...
#   25       предпочитать_VERB напарник_NOUN использовать_V...
#   26       предпочитать_VERB напарник_NOUN использовать_V...
#   27       предпочитать_VERB напарник_NOUN использовать_V...
#   28       предпочитать_VERB напарник_NOUN использовать_V...
#   29       предпочитать_VERB напарник_NOUN использовать_V...
#                                  ...
#   93319    ударить_VERB бояться_VERB бороться_VERB справе...
#   93320    ударить_VERB бояться_VERB бороться_VERB справе...
#   93321    ударить_VERB бояться_VERB бороться_VERB справе...
#   93322    ударить_VERB бояться_VERB бороться_VERB справе...
#   93323    ударить_VERB бояться_VERB бороться_VERB справе...
#   93324    ударить_VERB бояться_VERB бороться_VERB справе...
#   93325                                             вой_NOUN
#   93326                                             вой_NOUN
#   93327                                             вой_NOUN
#   93328                                             вой_NOUN
#   93329                                             вой_NOUN
#   93330                                             вой_NOUN
#   93331                                          дьявол_NOUN
#   93332                                          дьявол_NOUN
#   93333                                          дьявол_NOUN
#   93334                                          дьявол_NOUN
#   93335                                          дьявол_NOUN
#   93336                                          дьявол_NOUN
#   93337                               давать_VERB оттуда_ADV
#   93338                               давать_VERB оттуда_ADV
#   93339                               давать_VERB оттуда_ADV
#   93340                               давать_VERB оттуда_ADV
#   93341                               давать_VERB оттуда_ADV
#   93342                               давать_VERB оттуда_ADV
#   93343                              звать_VERB спенсер_NOUN
#   93344                              звать_VERB спенсер_NOUN
#   93345                              звать_VERB спенсер_NOUN
#   93346                              звать_VERB спенсер_NOUN
#   93347                              звать_VERB спенсер_NOUN
#   93348                              звать_VERB спенсер_NOUN
#   Name: context_1, Length: 46605, dtype: object,
#   0        кликнуть_VERB надпись_NOUN видео_NOUN звонок_NOUN
#   1        кликнуть_VERB надпись_NOUN видео_NOUN звонок_NOUN
#   2        кликнуть_VERB надпись_NOUN видео_NOUN звонок_NOUN
#   3        кликнуть_VERB надпись_NOUN видео_NOUN звонок_NOUN
#   4        кликнуть_VERB надпись_NOUN видео_NOUN звонок_NOUN
#   5        кликнуть_VERB надпись_NOUN видео_NOUN звонок_NOUN
#   6                                  бывать_VERB хороший_IGN
#   7                                  бывать_VERB хороший_IGN
#   8                                  бывать_VERB хороший_IGN
#   9                                  бывать_VERB хороший_IGN
#   10                                 бывать_VERB хороший_IGN
#   11                                 бывать_VERB хороший_IGN
#   12                                       это_PART ново_ADV
#   13                                       это_PART ново_ADV
#   14                                       это_PART ново_ADV
#   15                                       это_PART ново_ADV
#   16                                       это_PART ново_ADV
#   17                                       это_PART ново_ADV
#   18                                                ага_INTJ
#   19                                                ага_INTJ
#   20                                                ага_INTJ
#   21                                                ага_INTJ
#   22                                                ага_INTJ
#   23                                                ага_INTJ
#   24          предпочитать_VERB похитить_VERB подопытный_ADJ
#   25          предпочитать_VERB похитить_VERB подопытный_ADJ
#   26          предпочитать_VERB похитить_VERB подопытный_ADJ
#   27          предпочитать_VERB похитить_VERB подопытный_ADJ
#   28          предпочитать_VERB похитить_VERB подопытный_ADJ
#   29          предпочитать_VERB похитить_VERB подопытный_ADJ
#                                  ...
#   93319                             давать_VERB ударить_VERB
#   93320                             давать_VERB ударить_VERB
#   93321                             давать_VERB ударить_VERB
#   93322                             давать_VERB ударить_VERB
#   93323                             давать_VERB ударить_VERB
#   93324                             давать_VERB ударить_VERB
#   93325                              здоровый_ADJ робби_NOUN
#   93326                              здоровый_ADJ робби_NOUN
#   93327                              здоровый_ADJ робби_NOUN
#   93328                              здоровый_ADJ робби_NOUN
#   93329                              здоровый_ADJ робби_NOUN
#   93330                              здоровый_ADJ робби_NOUN
#   93331               ладный_ADJ возвращаться_VERB лифт_NOUN
#   93332               ладный_ADJ возвращаться_VERB лифт_NOUN
#   93333               ладный_ADJ возвращаться_VERB лифт_NOUN
#   93334               ладный_ADJ возвращаться_VERB лифт_NOUN
#   93335               ладный_ADJ возвращаться_VERB лифт_NOUN
#   93336               ладный_ADJ возвращаться_VERB лифт_NOUN
#   93337                                              эй_INTJ
#   93338                                              эй_INTJ
#   93339                                              эй_INTJ
#   93340                                              эй_INTJ
#   93341                                              эй_INTJ
#   93342                                              эй_INTJ
#   93343                прекрасный_ADJ решение_NOUN мисс_NOUN
#   93344                прекрасный_ADJ решение_NOUN мисс_NOUN
#   93345                прекрасный_ADJ решение_NOUN мисс_NOUN
#   93346                прекрасный_ADJ решение_NOUN мисс_NOUN
#   93347                прекрасный_ADJ решение_NOUN мисс_NOUN
#   93348                прекрасный_ADJ решение_NOUN мисс_NOUN
#   Name: context_2, Length: 46605, dtype: object]]
