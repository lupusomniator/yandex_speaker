# %%
import pickle
import pandas as pd

# %%
with open("canonized_clear.pickle",'rb') as file:
    asd = pickle.load(file)

# %%
asd[0].head()
# Out:
#       context_id context_2 context_1              context_0 reply_id  \
# 49  289676265247       NaN       NaN  [имя, дать, родитель]        0
# 50  289676265247       NaN       NaN  [имя, дать, родитель]        1
# 51  289676265247       NaN       NaN  [имя, дать, родитель]        2
# 52  289676265247       NaN       NaN  [имя, дать, родитель]        3
# 53  289676265247       NaN       NaN  [имя, дать, родитель]        4
#
#                         reply label    confidence
# 49  теперь вам дают и имена .  good  0.8019585199
# 50               полное имя ?   bad  0.9387921268
# 51                какое имя ?  good  0.7983988626
# 52       а твое имя - невер .  good  0.9076912001
# 53        а мое ханна грейс .  good  0.9912839575

# %%
asd[1].head()
# Out:
#       context_id context_2 context_1 context_0 reply_id  \
# 61  300113641606       NaN     [это]    [хотя]        0
# 62  300113641606       NaN     [это]    [хотя]        1
# 63  300113641606       NaN     [это]    [хотя]        2
# 64  300113641606       NaN     [это]    [хотя]        3
# 65  300113641606       NaN     [это]    [хотя]        4
#
#                         reply    label    confidence
# 61                     тише .     good  0.9291954342
# 62           я в <CENSORED> .      bad  0.9949661191
# 63    наверное это не важно .     good  0.7296121132
# 64  все в порядке , женщина .     good  0.8377676781
# 65                      что ?  neutral  0.9838724208

# %%
asd[2].head()
# Out:
#     context_id                           context_2 context_1  \
# 0  22579918886  [кликнуть, надпись, видео, звонок]  [видеть]
# 1  22579918886  [кликнуть, надпись, видео, звонок]  [видеть]
# 2  22579918886  [кликнуть, надпись, видео, звонок]  [видеть]
# 3  22579918886  [кликнуть, надпись, видео, звонок]  [видеть]
# 4  22579918886  [кликнуть, надпись, видео, звонок]  [видеть]
#
#                     context_0 reply_id                     reply    label  \
# 0  [ладный, повесить, трубка]        0                 не могу .     good
# 1  [ладный, повесить, трубка]        1    нет , звонить буду я .  neutral
# 2  [ладный, повесить, трубка]        2  слушай , я не мог уйти .      bad
# 3  [ладный, повесить, трубка]        3   я не прекращу звонить .     good
# 4  [ладный, повесить, трубка]        4              я звоню им .     good
#
#      confidence
# 0  0.8753516175
# 1  0.9009682113
# 2  0.8843202145
# 3  0.9825304673
# 4  0.8380535096
